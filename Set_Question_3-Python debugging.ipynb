# %%
#1.What is wrong with the following function definition, and how do you fix it?


def say_hello(name)
    print("Hello, " + name)

# %%
def say_hello(name):      #Missing collen
    print("Hello " , name) # replace + with comma

# %%
#2.What error will occur in the following code, and how do you fix it?


age = 25
print("I am " + age + " years old")

# %%
age = 25
print("I am " , age ," years old")   # string and integer can't be concatenated
# Out:
# I am  25  years old

# %%
#3.Question:
What is the issue with the following code?

def greet():
    message = "Hello"
print(message)

# %%
def greet():
    message = "Hello"
    print(message)     # print statement out of function 

greet()                 # function call
# Out:
# Hello

# %%
#4.What error will occur in the following code, and how do you fix it?

def add(a, b):
    return a + b

print(add(5))

# %%
def add(a, b):
    return a + b

print(add(5,4))     # two arguments shoould be passed for two parameters
# Out:
# 9

# %%
#5.What is wrong with this code?

def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False

# %%
def is_even(n):
    if n % 2 == 0:        # Logic mistake 
        return True
    else:
        return False
    
is_even(4)             # function call
# Out:
# True

# %%
#6.What happens when you run this code?

num = int("10a")
print(num)

# %%
num = "10a"   # 10a is not an integer
print(num)
# Out:
# 10a

# %%
#7.What will happen when you run the following code?


numbers = [1, 2, 3, 4]
numbers.sort().reverse()
print(numbers)

# %%
numbers = [1, 2, 3, 4]
numbers.sort()             # both operations need to be done seperately
numbers.reverse()
print(numbers)
# Out:
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?


numbers = [1, 2, 3]
numbers = numbers.append(4)
print(numbers)

# %%
# corrected code
numbers = [1, 2, 3]
numbers.append(4)    # list operation should not be stored in a new variable
print(numbers)
# Out:
# [1, 2, 3, 4]

# %%
#9.What will happen when you run the following code?


count = 10

def increment():
    count += 1
    print(count)

increment()

# %%
count = 10

def increment():
    global count     # count variable should be globalized inside the function
    count += 1
    print(count)

increment()
# Out:
# 11

# %%
#10.What error will occur in the following code?

text = "Python"
print(text[10])

# %%
text = "Python"
print(text[5])   # index out of bounce error
# Out:
# n
