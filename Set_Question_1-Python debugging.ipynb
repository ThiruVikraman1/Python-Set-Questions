# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
for i in range(5): #missing colon and wrong indendation
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
# corrected code
a = 10
b = "5"  # cannot concatenate string and integer
print(a + int(b)) #Type casting
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
def add_numbers(a,b): #missing colon
    return a+b

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
# Index error
numbers = [1,2,3,4] 
print(numbers[3])  #index corrected
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
print("Hello, World!")  #missing paranthesis
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
# A Number cannot be divided by 0
x = 5/1  #zero division error

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))  #cannot concatenate string and integer
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
# for the given range step -1 can't be used
for i in range(10,1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
# = is aggignment operator
# to compare values == should be used
x = 10
if x == 5:
    print('x is 5')

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
def greet(name): # Missing colon
    print("hello,"+name)
